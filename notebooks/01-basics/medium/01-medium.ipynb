# %% [markdown]
# ---
#
# ## Medium Assignment: Reusable Function
#
# **Objective:** Create a function that can be reused for any idea and audience
#
# **Your Task:**
# 1. Write a function called `describe_for_audience(idea: str, audience: str) -> str`
# 2. Function should:
#    - Accept idea and audience parameters
#    - Create an appropriate prompt
#    - Call ChatOpenAI
#    - Return the explanation
# 3. Add a docstring explaining what it does
# 4. Test it with at least 3 different audience/idea combinations
# 5. Verify explanations differ by audience
#
# **Success criteria:**
# - ✅ Function has correct signature
# - ✅ Function has docstring
# - ✅ Returns string
# - ✅ Works for different ideas
# - ✅ Works for different audiences
# - ✅ Explanations are audience-appropriate
#
# **Hints:**
# - Use f-strings for prompts
# - Extract `.content` from response
# - Test with at least 3 calls

# %%
# TODO: Write the function here
# def describe_for_audience(idea: str, audience: str) -> str:
#     """
#     YOUR DOCSTRING HERE
#     """
#     pass

# TODO: Test with 3 different combinations
# result1 = describe_for_audience(...)
# print(f"Test 1:\n{result1}\n")

# result2 = describe_for_audience(...)
# print(f"Test 2:\n{result2}\n")

# result3 = describe_for_audience(...)
# print(f"Test 3:\n{result3}")

print("✅ Medium assignment complete!")
