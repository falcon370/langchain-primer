# %% [markdown]
# ## Setup
#
# First, let's make sure we have the necessary imports and environment setup.

# %%
# Import required modules
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os

# Load environment variables
load_dotenv()

# Get API key from environment
api_key = os.getenv('OPENAI_API_KEY')

# Verify API key is loaded
if not api_key or not api_key.startswith('sk-'):
    raise ValueError('Invalid or missing OPENAI_API_KEY')

print("✅ Environment setup complete")

# %% [markdown]
# ---
#
# ## Easy Assignment: Multi-Audience Explanations
#
# **Objective:** Call ChatOpenAI and generate explanations for different audiences
#
# **Your Task:**
# 1. Create a ChatOpenAI instance with model='gpt-4' and temperature=0.7
# 2. Choose a topic (e.g., "Machine Learning", "Blockchain", "Cloud Computing")
# 3. Generate TWO explanations:
#    - One for a 10-year-old (use simple words)
#    - One for a CTO (use technical terms)
# 4. Print both explanations
#
# **Success criteria:**
# - ✅ ChatOpenAI initialized correctly
# - ✅ Two different explanations generated
# - ✅ Easy explanation is simple
# - ✅ CTO explanation is technical
# - ✅ Both are printed
#
# **Hints:**
# - Use `llm.invoke()` to call the LLM
# - Access response with `.content`
# - Craft different prompts for different audiences

# %%
# TODO: Initialize ChatOpenAI
# llm = ChatOpenAI(...)

# TODO: Choose a topic
# topic = "..."

# TODO: Create prompt for 10-year-old
# prompt_child = f"Explain {topic} ..."

# TODO: Call LLM for child explanation
# response_child = ...

# TODO: Print result
# print(...)

# TODO: Create prompt for CTO
# prompt_cto = f"Explain {topic} ..."

# TODO: Call LLM for CTO explanation
# response_cto = ...

# TODO: Print result
# print(...)

print("✅ Easy assignment complete!")
