# %% [markdown]
# ---
#
# ## Hard Assignment: Validation & Logging
#
# **Objective:** Add input validation and CSV logging to track API calls
#
# **Your Task:**
# 1. Create a validation function that checks:
#    - Both inputs are non-empty strings
#    - Idea is not longer than 500 characters
#    - Audience is not longer than 100 characters
# 2. Create a logging function that:
#    - Creates `logs/` directory if it doesn't exist
#    - Appends to `logs/module01_logs.csv`
#    - Records: timestamp, idea, audience, response_length
#    - DOES NOT log API keys
# 3. Create wrapper function that:
#    - Validates inputs
#    - Calls describe_for_audience
#    - Logs the request
#    - Returns result
# 4. Handle errors gracefully (raise ValueError with message)
# 5. Test with both valid and invalid inputs
#
# **Success criteria:**
# - ✅ Validation function works
# - ✅ CSV file created
# - ✅ Each call logged with correct fields
# - ✅ API keys never logged
# - ✅ Error handling works
# - ✅ Invalid inputs rejected
#
# **Hints:**
# - Use `import csv`, `from datetime import datetime`, `import os`
# - `datetime.now().isoformat()` for timestamp
# - Open file with `'a'` mode to append
# - Test error handling with `try/except`

# %%
import csv
from datetime import datetime

# TODO: Create validation function
# def validate_input(idea: str, audience: str) -> bool:
#     ...
#     pass

# TODO: Create logging function
# def log_request(idea: str, audience: str, response: str):
#     ...
#     pass

# TODO: Create wrapper function
# def describe_with_logging(idea: str, audience: str) -> str:
#     ...
#     pass

# TODO: Test with valid input
# try:
#     result = describe_with_logging(...)
#     print(f"Success: {len(result)} characters logged")
# except ValueError as e:
#     print(f"Error: {e}")

# TODO: Test with invalid input
# try:
#     result = describe_with_logging(...)
# except ValueError as e:
#     print(f"Caught error as expected: {e}")

# TODO: Verify CSV was created
# import os
# if os.path.exists('logs/module01_logs.csv'):
#     with open('logs/module01_logs.csv', 'r') as f:
#         print("\nCSV contents:")
#         print(f.read())

print("✅ Hard assignment complete!")
