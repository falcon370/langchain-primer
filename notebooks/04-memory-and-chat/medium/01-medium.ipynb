# %% [markdown]
# ## Medium: Summary Memory
#
# **Task:** Use ConversationSummaryMemory to condense memory (more efficient)
#
# **Your task:**
# 1. Create ConversationSummaryMemory (uses LLM to summarize)
# 2. Create ConversationChain with summary memory
# 3. Have 5+ turn conversation about your preferences
# 4. Memory should condense long histories
#
# **Hints:**
# - SummaryMemory uses LLM to create summaries
# - More efficient than BufferMemory for long conversations

# %%
# TODO: Create summary memory
# summary_memory = ConversationSummaryMemory(llm=llm)

# TODO: Create conversation chain
# conversation_summary = ConversationChain(llm=llm, memory=summary_memory)

# TODO: Have multiple turns about preferences
# messages = [
#     "I like pizza",
#     "I also like pasta",
#     "My favorite color is blue",
#     "I enjoy programming",
#     "What do I like?"
# ]

# for msg in messages:
#     response = conversation_summary.invoke({"input": msg})
#     print(f"Input: {msg}")
#     print(f"Response: {response['response']}\n")

print("✅ Medium complete")
