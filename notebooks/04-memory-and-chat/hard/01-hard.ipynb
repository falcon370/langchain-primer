# %% [markdown]
# ## Hard: Session Isolation
#
# **Task:** Manage multiple independent conversation sessions
#
# **Your task:**
# 1. Create SessionManager class that:
#    - Stores separate memories for different users
#    - Creates memory on first access
#    - Returns existing memory for returning users
# 2. Implement `get_or_create_session(session_id)` method
# 3. Implement `chat(session_id, message)` method
# 4. Test with 2+ different users
# 5. Verify each user has separate memory
#
# **Hints:**
# - Use dict to store sessions: `self.sessions = {}`
# - Each session_id gets own ConversationBufferMemory

# %%
# TODO: Create SessionManager class
# class SessionManager:
#     def __init__(self):
#         pass
#     
#     def get_or_create_session(self, session_id: str):
#         pass
#     
#     def chat(self, session_id: str, message: str) -> str:
#         pass

# TODO: Test with multiple users
# manager = SessionManager()

# # User 1
# manager.chat("user1", "I'm Bob")
# response1 = manager.chat("user1", "Who am I?")
# print(f"User1: {response1}\n")

# # User 2 (different session)
# manager.chat("user2", "I'm Alice")
# response2 = manager.chat("user2", "Who am I?")
# print(f"User2: {response2}\n")

# # Verify isolation
# response3 = manager.chat("user1", "Who am I?")
# print(f"User1 again: {response3}")

print("✅ Hard complete")
