# %% [markdown]
# ## Hard: Citations & Confidence
#
# **Task:** Return answers WITH source citations and confidence scores
#
# **Your task:**
# 1. Create CitationChain wrapper that:
#    - Gets answer from RetrievalQA
#    - Returns source documents used
#    - Calculates confidence (0-1) based on retrieval score
# 2. Return format:
#    ```json
#    {
#      "answer": "...",
#      "citations": ["source 1", "source 2"],
#      "confidence": 0.85
#    }
#    ```
# 3. Test with questions that:
#    - Have clear answers in documents
#    - Have ambiguous answers
#    - Have no good matches
# 4. Verify confidence adjusts appropriately
#
# **Hints:**
# - `similarity_search_with_scores()` returns scores
# - Confidence = average of retrieval scores
# - Add threshold: if confidence < 0.5, say "uncertain"

# %%
# TODO: Create citation chain class
# class CitationChain:
#     def __init__(self, qa_chain, vector_store, confidence_threshold=0.5):
#         pass
#     
#     def answer(self, question: str) -> dict:
#         # Retrieve with scores
#         # Calculate confidence
#         # Get answer
#         # Extract citations
#         # Return formatted result
#         pass

# TODO: Create instance
# citation_chain = CitationChain(qa, vector_store)

# TODO: Test with different questions
# questions = [
#     "Clear question with good answers",
#     "Ambiguous question",
#     "Question not in documents"
# ]

# for q in questions:
#     result = citation_chain.answer(q)
#     print(f"Q: {q}")
#     print(f"Answer: {result['answer']}")
#     print(f"Confidence: {result['confidence']:.2f}")
#     print(f"Citations: {result['citations']}\n")

print("✅ Hard complete")
