# %% [markdown]
# ## Medium: Retrieval Chain
#
# **Task:** Build RetrievalQA chain that answers questions using retrieved documents
#
# **Your task:**
# 1. Create RetrievalQA with:
#    - LLM
#    - Vector store retriever
#    - chain_type="stuff" (simple concatenation)
# 2. Ask 3 questions about your documents
# 3. Verify answers use document content
# 4. Track which documents were retrieved
#
# **Hints:**
# - Use `retriever = vector_store.as_retriever(k=3)`
# - Result includes "source_documents"
# - Compare answer to original documents

# %%
# TODO: Create retriever
# retriever = vector_store.as_retriever(k=3)

# TODO: Create RetrievalQA chain
# qa = RetrievalQA.from_chain_type(
#     llm=llm,
#     chain_type="stuff",
#     retriever=retriever
# )

# TODO: Ask questions
# questions = [
#     "What is ...",
#     "How does ...",
#     "Explain ..."
# ]

# for q in questions:
#     result = qa.invoke({"query": q})
#     print(f"Q: {q}")
#     print(f"A: {result['result']}")
#     print(f"Sources: {len(result['source_documents'])} documents\n")

print("✅ Medium complete")
