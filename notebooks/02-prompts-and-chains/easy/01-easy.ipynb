# %% [markdown]
# ## Setup

# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os

load_dotenv()
llm = ChatOpenAI(api_key=os.getenv('OPENAI_API_KEY'), model='gpt-4')

print("✅ Setup complete")

# %% [markdown]
# ## Easy: PromptTemplate Basics
#
# **Task:** Create a PromptTemplate with at least 3 variables
#
# **Your task:**
# 1. Create PromptTemplate with variables: `{topic}`, `{audience}`, `{length}`
# 2. Write a template that uses all 3 variables
# 3. Format the template with specific values
# 4. Print the resulting prompt
#
# **Hints:**
# - `input_variables` is a list of variable names
# - `template` is a string with `{variable_name}` placeholders
# - Use `.format()` method to fill variables

# %%
# TODO: Create PromptTemplate
# template = PromptTemplate(
#     input_variables=[...],
#     template="..."
# )

# TODO: Format with values
# prompt = template.format(...)

# TODO: Print result
# print(prompt)

print("✅ Easy complete")
