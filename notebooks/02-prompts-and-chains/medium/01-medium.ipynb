# %% [markdown]
# ## Medium: LLMChain
#
# **Task:** Build an LLMChain that combines prompt template with LLM
#
# **Your task:**
# 1. Create a PromptTemplate for summarization
# 2. Create LLMChain with the template and LLM
# 3. Call the chain with input variables
# 4. Extract and print the result
#
# **Hints:**
# - LLMChain takes `llm` and `prompt` parameters
# - Call with `.invoke({"variable": value})`
# - Result is a dict, extract with `result['text']`

# %%
# TODO: Create PromptTemplate for summarization
# prompt_template = PromptTemplate(...)

# TODO: Create LLMChain
# chain = LLMChain(...)

# TODO: Invoke chain
# result = chain.invoke({...})

# TODO: Print result
# print(...)

print("✅ Medium complete")
