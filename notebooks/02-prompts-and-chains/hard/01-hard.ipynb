# %% [markdown]
# ## Hard: Multi-Chain Safety System
#
# **Task:** Create two chains - one to classify if topic is safe, another to generate content
#
# **Your task:**
# 1. Create a classifier chain that takes a topic and returns "SAFE" or "UNSAFE"
# 2. Create a content generation chain
# 3. Create a wrapper function that:
#    - Calls classifier first
#    - If SAFE, generates content
#    - If UNSAFE, returns fallback message
# 4. Test with both safe and unsafe topics
#
# **Hints:**
# - Parse response to check if "SAFE" in `response['text'].upper()`
# - Use multiple chains in sequence
# - Test with "renewable energy" (safe) and something potentially unsafe

# %%
# TODO: Create classifier prompt and chain
# classifier_prompt = PromptTemplate(...)
# classifier_chain = LLMChain(...)

# TODO: Create content prompt and chain
# content_prompt = PromptTemplate(...)
# content_chain = LLMChain(...)

# TODO: Create wrapper function
# def safe_generate_content(topic: str) -> str:
#     classification = classifier_chain.invoke({...})
#     if "SAFE" in classification['text'].upper():
#         result = content_chain.invoke({...})
#         return result['text']
#     else:
#         return "..."

# TODO: Test with safe topic
# result = safe_generate_content("renewable energy")
# print(result)

# TODO: Test with potentially unsafe topic
# result = safe_generate_content("...")
# print(result)

print("✅ Hard complete")
