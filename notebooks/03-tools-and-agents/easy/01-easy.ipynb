# %% [markdown]
# ## Setup

# %%
from langchain_core.tools import tool
from langchain.agents import create_react_agent, AgentExecutor
from langchain.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os

load_dotenv()
llm = ChatOpenAI(api_key=os.getenv('OPENAI_API_KEY'), model='gpt-4')

print("✅ Setup complete")

# %% [markdown]
# ## Easy: Create Tools
#
# **Task:** Define tools using @tool decorator
#
# **Your task:**
# 1. Create a calculator tool that evaluates mathematical expressions
# 2. Create a doc linker tool that returns documentation links
# 3. Test both tools
#
# **Hints:**
# - Use `@tool` decorator
# - Add docstring (becomes tool description)
# - Return string result

# %%
# TODO: Create calculator tool
# @tool
# def calculator(expression: str) -> str:
#     """Evaluate mathematical expressions"""
#     pass

# TODO: Create doc linker tool
# @tool
# def link_documentation(topic: str) -> str:
#     """Link to relevant documentation"""
#     pass

# TODO: Test tools
# result1 = calculator.invoke({"expression": "2 + 2"})
# print(f"Calculator: {result1}")

# result2 = link_documentation.invoke({"topic": "python"})
# print(f"Docs: {result2}")

print("✅ Easy complete")
