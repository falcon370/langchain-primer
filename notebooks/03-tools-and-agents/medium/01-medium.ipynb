# %% [markdown]
# ## Medium: Build Agent
#
# **Task:** Create an agent that selects and uses tools
#
# **Your task:**
# 1. Create agent with your tools
# 2. Create AgentExecutor
# 3. Give agent a task ("What is 15 * 3?")
# 4. Agent should choose calculator tool and solve
#
# **Hints:**
# - Pass tools list to create_react_agent
# - AgentExecutor wraps agent and tools
# - Use `.invoke({"input": question})`

# %%
# TODO: Create agent
# tools = [...]
# agent = create_react_agent(llm, tools, ...)
# executor = AgentExecutor(...)

# TODO: Run agent
# result = executor.invoke({"input": "What is 15 * 3?"})
# print(f"Agent response: {result['output']}")

print("✅ Medium complete")
