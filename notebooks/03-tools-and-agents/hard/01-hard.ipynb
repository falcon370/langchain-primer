# %% [markdown]
# ## Hard: Rate Limiting & Logging
#
# **Task:** Add rate limiting and log tool usage
#
# **Your task:**
# 1. Create RateLimiter class that:
#    - Tracks calls in a time window
#    - Has `is_allowed()` method
#    - Prevents exceeding max_calls
# 2. Create logging function that writes to `logs/tools.jsonl`
# 3. Create wrapper that checks rate limit before allowing tool call
# 4. Test both allowed and rate-limited scenarios
#
# **Hints:**
# - Use `time.time()` for current timestamp
# - Use `json.dumps()` for logging
# - Filter old timestamps: `calls = [c for c in calls if now - c < time_window]`

# %%
import json
import time
from datetime import datetime

# TODO: Create RateLimiter class
# class RateLimiter:
#     def __init__(self, max_calls: int, time_window: int):
#         pass
#     def is_allowed(self) -> bool:
#         pass

# TODO: Create logging function
# def log_tool_usage(tool_name: str, input_data: str, result: str):
#     pass

# TODO: Test rate limiting
# limiter = RateLimiter(max_calls=5, time_window=10)
# for i in range(7):
#     if limiter.is_allowed():
#         log_tool_usage("calculator", "2+2", "4")
#         print(f"Call {i+1}: allowed")
#     else:
#         print(f"Call {i+1}: rate limited")

print("✅ Hard complete")
